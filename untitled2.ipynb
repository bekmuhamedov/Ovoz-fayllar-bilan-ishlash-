# %% [markdown]
# <a href="https://colab.research.google.com/github/bekmuhamedov/Ovoz-fayllar-bilan-ishlash-/blob/main/untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Untitled4.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1oCUK0E-e8W1ouC-oqfTs1DeKDUJ1Kype
"""

import matplotlib.pyplot as plt
import numpy as np

x=np.array([1,2,6,8])
y=np.array([3,8,1,10])

plt.plot(x,y)
plt.show()

import matplotlib.pyplot as plt
import numpy as np

y=np.array([3,8,1,10])

plt.plot(y,marker='x')
plt.show()

import matplotlib.pyplot as
# Out:
#   File "<ipython-input-1-49f1928ea3fb>", line 27
#     import matplotlib.pyplot as
#                                ^
# SyntaxError: invalid syntax
